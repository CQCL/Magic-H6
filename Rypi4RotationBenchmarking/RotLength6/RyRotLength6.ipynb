# %%
import json
import math

# %%
qasm = '''

OPENQASM 2.0;
include "hqslib1.inc";
qreg q0[6];
qreg q1[6];
qreg q2[6];


qreg a0[2];


creg init0[2];
creg meas0[6];

creg magic0[6];
creg magic1[6];
creg magic2[6];
creg magic3[6];
creg magic4[6];
creg magic5[6];



creg hcheck0[2];
creg hcheck1[2];
creg hcheck2[2];
creg hcheck3[2];
creg hcheck4[2];
creg hcheck5[2];




creg ycheck0[1];
creg ycheck1[1];
creg ycheck2[1];
creg ycheck3[1];
creg ycheck4[1];
creg ycheck5[1];


creg xcheck0[2];
creg xcheck1[2];
creg xcheck2[2];
creg xcheck3[2];
creg xcheck4[2];
creg xcheck5[2];


creg flags0[2];
creg flags1[2];
creg flags2[2];
creg flags3[2];
creg flags4[2];
creg flags5[2];


creg twirl[6];


creg scratch[6];
creg rng_index[32];

gate chh() a,b
{
   ry(-pi/4) b;
   cz a,b;
   ry(pi/4) b;
}

//Generate binary sequence of length 6 for twirling
RNGseed(1);
rng_index = JOB_shotnum;
RNGindex(rng_index);
RNGbound(64);
twirl = RNGnum();


h q0[0];
cx q0[0], a0[0];
cx q0[0], q0[1];
cx q0[0], q0[4];
cx q0[0], q0[5];
cx q0[0], a0[0];
measure a0[0] -> init0[0];
reset a0[0];

h q0[2];
cx q0[2], a0[1];
cx q0[2], q0[3];
cx q0[2], q0[4];
cx q0[2], q0[5];
cx q0[2], a0[1];
measure a0[1] -> init0[1];
reset a0[1];



// Begin First Magic State injection
ry(pi/4) q1[0];

h q1[1];
sdg q1[1];

h q1[2];
h q1[4];
cx q1[2], q1[3];
cx q1[4], q1[5];
cx q1[2], q1[0];
cx q1[3], q1[1];
cx q1[0], q1[4];
cx q1[1], q1[5];
cx q1[4], q1[2];
cx q1[5], q1[3];


h a0[0];
cx a0[0], a0[1];


chh a0[0], q1[0];
cx a0[1], q1[1];
chh a0[1], q1[1];
chh a0[0], q1[2];
cx a0[1], q1[3];
chh a0[1], q1[3];
chh a0[0], q1[4];
cx a0[1], q1[5];
chh a0[1], q1[5];



cx a0[0], a0[1];
t a0[0];
h a0[0];

measure a0 -> hcheck0;
reset a0;


h a0[0];
cy a0[0], q1[1];
cy a0[0], q1[3];
cy a0[0], q1[5];
h a0[0];
measure a0[0] -> ycheck0[0];
reset a0[0];




// Twirl here
if(twirl[0] == 1)h q1;
if(twirl[0] == 1)x q1[1];
if(twirl[0] == 1)x q1[3];
if(twirl[0] == 1)x q1[5];

cy q1, q0;

sdg q1;
h q1;
measure q1 -> magic0;
reset q1;


scratch[0] = magic0[0]^magic0[2];
scratch[0] = scratch[0]^magic0[4];

if(scratch[0] == 0) ry(-pi/2) q0;

// Twirl here
h a0[0];
cx a0[0], q0[0];
cx a0[0], a0[1];
cx a0[0], q0[1];
cx a0[0], q0[2];
cx a0[0], a0[1];
cx a0[0], q0[3];
h a0[0];
measure a0[0] -> xcheck0[0];
measure a0[1] -> flags0[0];
reset a0;


h a0[0];
cx a0[0], q0[2];
cx a0[0], a0[1];
cx a0[0], q0[3];
cx a0[0], q0[4];
cx a0[0], a0[1];
cx a0[0], q0[5];
h a0[0];
measure a0[0] -> xcheck0[1];
measure a0[1] -> flags0[1];
reset a0;





// Begin Second Magic State injection
ry(pi/4) q2[0];

h q2[1];
sdg q2[1];

h q2[2];
h q2[4];
cx q2[2], q2[3];
cx q2[4], q2[5];
cx q2[2], q2[0];
cx q2[3], q2[1];
cx q2[0], q2[4];
cx q2[1], q2[5];
cx q2[4], q2[2];
cx q2[5], q2[3];


h a0[0];
cx a0[0], a0[1];


chh a0[0], q2[0];
cx a0[1], q2[1];
chh a0[1], q2[1];
chh a0[0], q2[2];
cx a0[1], q2[3];
chh a0[1], q2[3];
chh a0[0], q2[4];
cx a0[1], q2[5];
chh a0[1], q2[5];



cx a0[0], a0[1];
t a0[0];
h a0[0];

measure a0 -> hcheck1;
reset a0;


h a0[0];
cy a0[0], q2[1];
cy a0[0], q2[3];
cy a0[0], q2[5];
h a0[0];
measure a0[0] -> ycheck1[0];
reset a0[0];




// Twirl here
if(twirl[1] == 1)h q2;
if(twirl[1] == 1)x q2[1];
if(twirl[1] == 1)x q2[3];
if(twirl[1] == 1)x q2[5];

cy q2, q0;

sdg q2;
h q2;
measure q2 -> magic1;
reset q2;


scratch[0] = magic1[0]^magic1[2];
scratch[0] = scratch[0]^magic1[4];

if(scratch[0] == 0) ry(-pi/2) q0;

//We must extract the X syndromes
h a0[0];
cx a0[0], q0[0];
cx a0[0], a0[1];
cx a0[0], q0[1];
cx a0[0], q0[2];
cx a0[0], a0[1];
cx a0[0], q0[3];
h a0[0];
measure a0[0] -> xcheck1[0];
measure a0[1] -> flags1[0];
reset a0;


h a0[0];
cx a0[0], q0[2];
cx a0[0], a0[1];
cx a0[0], q0[3];
cx a0[0], q0[4];
cx a0[0], a0[1];
cx a0[0], q0[5];
h a0[0];
measure a0[0] -> xcheck1[1];
measure a0[1] -> flags1[1];
reset a0;




// Begin Third Magic State injection
ry(pi/4) q1[0];

h q1[1];
sdg q1[1];

h q1[2];
h q1[4];
cx q1[2], q1[3];
cx q1[4], q1[5];
cx q1[2], q1[0];
cx q1[3], q1[1];
cx q1[0], q1[4];
cx q1[1], q1[5];
cx q1[4], q1[2];
cx q1[5], q1[3];


h a0[0];
cx a0[0], a0[1];


chh a0[0], q1[0];
cx a0[1], q1[1];
chh a0[1], q1[1];
chh a0[0], q1[2];
cx a0[1], q1[3];
chh a0[1], q1[3];
chh a0[0], q1[4];
cx a0[1], q1[5];
chh a0[1], q1[5];



cx a0[0], a0[1];
t a0[0];
h a0[0];

measure a0 -> hcheck2;
reset a0;


h a0[0];
cy a0[0], q1[1];
cy a0[0], q1[3];
cy a0[0], q1[5];
h a0[0];
measure a0[0] -> ycheck2[0];
reset a0[0];




// Twirl here
if(twirl[2] == 1)h q1;
if(twirl[2] == 1)x q1[1];
if(twirl[2] == 1)x q1[3];
if(twirl[2] == 1)x q1[5];

cy q1, q0;

sdg q1;
h q1;
measure q1 -> magic2;
reset q1;


scratch[0] = magic2[0]^magic2[2];
scratch[0] = scratch[0]^magic2[4];

if(scratch[0] == 0) ry(-pi/2) q0;

//We must extract the X syndromes
h a0[0];
cx a0[0], q0[0];
cx a0[0], a0[1];
cx a0[0], q0[1];
cx a0[0], q0[2];
cx a0[0], a0[1];
cx a0[0], q0[3];
h a0[0];
measure a0[0] -> xcheck2[0];
measure a0[1] -> flags2[0];
reset a0;


h a0[0];
cx a0[0], q0[2];
cx a0[0], a0[1];
cx a0[0], q0[3];
cx a0[0], q0[4];
cx a0[0], a0[1];
cx a0[0], q0[5];
h a0[0];
measure a0[0] -> xcheck2[1];
measure a0[1] -> flags2[1];
reset a0;





// Begin Fourth Magic State injection
ry(pi/4) q2[0];

h q2[1];
sdg q2[1];

h q2[2];
h q2[4];
cx q2[2], q2[3];
cx q2[4], q2[5];
cx q2[2], q2[0];
cx q2[3], q2[1];
cx q2[0], q2[4];
cx q2[1], q2[5];
cx q2[4], q2[2];
cx q2[5], q2[3];


h a0[0];
cx a0[0], a0[1];


chh a0[0], q2[0];
cx a0[1], q2[1];
chh a0[1], q2[1];
chh a0[0], q2[2];
cx a0[1], q2[3];
chh a0[1], q2[3];
chh a0[0], q2[4];
cx a0[1], q2[5];
chh a0[1], q2[5];



cx a0[0], a0[1];
t a0[0];
h a0[0];

measure a0 -> hcheck3;
reset a0;


h a0[0];
cy a0[0], q2[1];
cy a0[0], q2[3];
cy a0[0], q2[5];
h a0[0];
measure a0[0] -> ycheck3[0];
reset a0[0];




// Twirl here
if(twirl[3] == 1)h q2;
if(twirl[3] == 1)x q2[1];
if(twirl[3] == 1)x q2[3];
if(twirl[3] == 1)x q2[5];

cy q2, q0;

sdg q2;
h q2;
measure q2 -> magic3;
reset q2;


scratch[0] = magic3[0]^magic3[2];
scratch[0] = scratch[0]^magic3[4];

if(scratch[0] == 0) ry(-pi/2) q0;

//We must extract the X syndromes
h a0[0];
cx a0[0], q0[0];
cx a0[0], a0[1];
cx a0[0], q0[1];
cx a0[0], q0[2];
cx a0[0], a0[1];
cx a0[0], q0[3];
h a0[0];
measure a0[0] -> xcheck3[0];
measure a0[1] -> flags3[0];
reset a0;


h a0[0];
cx a0[0], q0[2];
cx a0[0], a0[1];
cx a0[0], q0[3];
cx a0[0], q0[4];
cx a0[0], a0[1];
cx a0[0], q0[5];
h a0[0];
measure a0[0] -> xcheck3[1];
measure a0[1] -> flags3[1];
reset a0;

// Begin Fifth Magic State injection
ry(pi/4) q1[0];

h q1[1];
sdg q1[1];

h q1[2];
h q1[4];
cx q1[2], q1[3];
cx q1[4], q1[5];
cx q1[2], q1[0];
cx q1[3], q1[1];
cx q1[0], q1[4];
cx q1[1], q1[5];
cx q1[4], q1[2];
cx q1[5], q1[3];


h a0[0];
cx a0[0], a0[1];


chh a0[0], q1[0];
cx a0[1], q1[1];
chh a0[1], q1[1];
chh a0[0], q1[2];
cx a0[1], q1[3];
chh a0[1], q1[3];
chh a0[0], q1[4];
cx a0[1], q1[5];
chh a0[1], q1[5];



cx a0[0], a0[1];
t a0[0];
h a0[0];

measure a0 -> hcheck4;
reset a0;


h a0[0];
cy a0[0], q1[1];
cy a0[0], q1[3];
cy a0[0], q1[5];
h a0[0];
measure a0[0] -> ycheck4[0];
reset a0[0];




// Twirl here
if(twirl[4] == 1)h q1;
if(twirl[4] == 1)x q1[1];
if(twirl[4] == 1)x q1[3];
if(twirl[4] == 1)x q1[5];

cy q1, q0;

sdg q1;
h q1;
measure q1 -> magic4;
reset q1;


scratch[0] = magic4[0]^magic4[2];
scratch[0] = scratch[0]^magic4[4];

if(scratch[0] == 0) ry(-pi/2) q0;

//We must extract the X syndromes
h a0[0];
cx a0[0], q0[0];
cx a0[0], a0[1];
cx a0[0], q0[1];
cx a0[0], q0[2];
cx a0[0], a0[1];
cx a0[0], q0[3];
h a0[0];
measure a0[0] -> xcheck4[0];
measure a0[1] -> flags4[0];
reset a0;


h a0[0];
cx a0[0], q0[2];
cx a0[0], a0[1];
cx a0[0], q0[3];
cx a0[0], q0[4];
cx a0[0], a0[1];
cx a0[0], q0[5];
h a0[0];
measure a0[0] -> xcheck4[1];
measure a0[1] -> flags4[1];
reset a0;





// Begin Sixth Magic State injection
ry(pi/4) q2[0];

h q2[1];
sdg q2[1];

h q2[2];
h q2[4];
cx q2[2], q2[3];
cx q2[4], q2[5];
cx q2[2], q2[0];
cx q2[3], q2[1];
cx q2[0], q2[4];
cx q2[1], q2[5];
cx q2[4], q2[2];
cx q2[5], q2[3];


h a0[0];
cx a0[0], a0[1];


chh a0[0], q2[0];
cx a0[1], q2[1];
chh a0[1], q2[1];
chh a0[0], q2[2];
cx a0[1], q2[3];
chh a0[1], q2[3];
chh a0[0], q2[4];
cx a0[1], q2[5];
chh a0[1], q2[5];



cx a0[0], a0[1];
t a0[0];
h a0[0];

measure a0 -> hcheck5;
reset a0;


h a0[0];
cy a0[0], q2[1];
cy a0[0], q2[3];
cy a0[0], q2[5];
h a0[0];
measure a0[0] -> ycheck5[0];
reset a0[0];




// Twirl here
if(twirl[5] == 1)h q2;
if(twirl[5] == 1)x q2[1];
if(twirl[5] == 1)x q2[3];
if(twirl[5] == 1)x q2[5];

cy q2, q0;

sdg q2;
h q2;
measure q2 -> magic5;
reset q2;


scratch[0] = magic5[0]^magic5[2];
scratch[0] = scratch[0]^magic5[4];

if(scratch[0] == 0) ry(-pi/2) q0;

//We must extract the X syndromes
h a0[0];
cx a0[0], q0[0];
cx a0[0], a0[1];
cx a0[0], q0[1];
cx a0[0], q0[2];
cx a0[0], a0[1];
cx a0[0], q0[3];
h a0[0];
measure a0[0] -> xcheck5[0];
measure a0[1] -> flags5[0];
reset a0;


h a0[0];
cx a0[0], q0[2];
cx a0[0], a0[1];
cx a0[0], q0[3];
cx a0[0], q0[4];
cx a0[0], a0[1];
cx a0[0], q0[5];
h a0[0];
measure a0[0] -> xcheck5[1];
measure a0[1] -> flags5[1];
reset a0;




h q0;
measure q0 -> meas0;
'''

# %%
with open("RyLength6.json", "r") as file:
    jobs = json.load(file)

# %%
def checks(r,i):

    if (r['init0'][i] != '00'):
        return False
    if (r['hcheck0'][i] != '00'):
        return False
    if (r['hcheck1'][i] != '00'):
       return False
    if (r['hcheck2'][i] != '00'):
       return False
    if (r['hcheck3'][i] != '00'):
       return False
    if (r['hcheck4'][i] != '00'):
       return False
    if (r['hcheck5'][i] != '00'):
       return False
    
    meas0 = r['meas0'][i]
    if (int(meas0[5]) + int(meas0[4]) + int(meas0[3]) + int(meas0[2]))%2 == 1:
        return False
    if (int(meas0[3]) + int(meas0[2]) + int(meas0[1]) + int(meas0[0]))%2 == 1:
        return False



    meas0 = r['magic0'][i]
    if (int(meas0[5]) + int(meas0[4]) + int(meas0[3]) + int(meas0[2]))%2 == 1:
        return False
    if (int(meas0[3]) + int(meas0[2]) + int(meas0[1]) + int(meas0[0]))%2 == 1:
        return False

    meas0 = r['magic1'][i]
    if (int(meas0[5]) + int(meas0[4]) + int(meas0[3]) + int(meas0[2]))%2 == 1:
        return False
    if (int(meas0[3]) + int(meas0[2]) + int(meas0[1]) + int(meas0[0]))%2 == 1:
        return False
    meas0 = r['magic2'][i]
    if (int(meas0[5]) + int(meas0[4]) + int(meas0[3]) + int(meas0[2]))%2 == 1:
        return False
    if (int(meas0[3]) + int(meas0[2]) + int(meas0[1]) + int(meas0[0]))%2 == 1:
        return False
    meas0 = r['magic3'][i]
    if (int(meas0[5]) + int(meas0[4]) + int(meas0[3]) + int(meas0[2]))%2 == 1:
        return False
    if (int(meas0[3]) + int(meas0[2]) + int(meas0[1]) + int(meas0[0]))%2 == 1:
        return False
    meas0 = r['magic4'][i]
    if (int(meas0[5]) + int(meas0[4]) + int(meas0[3]) + int(meas0[2]))%2 == 1:
        return False
    if (int(meas0[3]) + int(meas0[2]) + int(meas0[1]) + int(meas0[0]))%2 == 1:
        return False
    meas0 = r['magic5'][i]
    if (int(meas0[5]) + int(meas0[4]) + int(meas0[3]) + int(meas0[2]))%2 == 1:
        return False
    if (int(meas0[3]) + int(meas0[2]) + int(meas0[1]) + int(meas0[0]))%2 == 1:
        return False
    
    if (r['ycheck0'][i] != '0'):
        return False
    if (r['xcheck0'][i] != '00'):
        return False
    if (r['flags0'][i] != '00'):
        return False
    
    
    if (r['ycheck1'][i] != '0'):
        return False
    if (r['xcheck1'][i] != '00'):
       return False
    if (r['flags1'][i] != '00'):
       return False
        
    if (r['ycheck2'][i] != '0'):
        return False
    if (r['xcheck2'][i] != '00'):
       return False
    if (r['flags2'][i] != '00'):
       return False

    if (r['ycheck3'][i] != '0'):
        return False
    if (r['xcheck3'][i] != '00'):
       return False
    if (r['flags3'][i] != '00'):
       return False

    if (r['ycheck4'][i] != '0'):
        return False
    if (r['xcheck4'][i] != '00'):
       return False
    if (r['flags4'][i] != '00'):
       return False

    if (r['ycheck5'][i] != '0'):
        return False
    if (r['xcheck5'][i] != '00'):
       return False
    if (r['flags5'][i] != '00'):
       return False
    
    return True

def non_gate_checks(r,i):

    if (r['init0'][i] != '00'):
        return False
    if (r['hcheck0'][i] != '00'):
        return False
    if (r['hcheck1'][i] != '00'):
       return False
    if (r['hcheck2'][i] != '00'):
       return False
    if (r['hcheck3'][i] != '00'):
       return False
    if (r['hcheck4'][i] != '00'):
       return False
    if (r['hcheck5'][i] != '00'):
       return False
    meas0 = r['meas0'][i]
    if (int(meas0[5]) + int(meas0[4]) + int(meas0[3]) + int(meas0[2]))%2 == 1:
        return False
    if (int(meas0[3]) + int(meas0[2]) + int(meas0[1]) + int(meas0[0]))%2 == 1:
        return False
    if (r['ycheck0'][i] != '0'):
        return False
    if (r['ycheck1'][i] != '0'):
        return False
    if (r['ycheck2'][i] != '0'):
        return False
    if (r['ycheck3'][i] != '0'):
        return False
    if (r['ycheck4'][i] != '0'):
        return False
    if (r['ycheck5'][i] != '0'):
        return False
    return True

def success(r,i):
    meas0 = r['meas0'][i]
    return (int(meas0[5]) + int(meas0[3]) + int(meas0[1]))%2 == 0

# %%
import math
totals = 0
totals_no_gate_checks = 0
failures = 0
shots = 0
for j in jobs:
    r = j['results']
    for i in range(0,len(r['hcheck1'])):
        shots += 1
        if (checks(r,i)):
            totals += 1
            if (not success(r,i)):
                failures += 1
        if (non_gate_checks(r,i)):
            totals_no_gate_checks += 1
print('failures:', failures, 'totals:', totals)
print('logical failure rate:', failures/totals)
print('total accept rate:', totals/shots, 'standard deviation:', math.sqrt((totals/shots)*(shots-totals))/shots)
print('accept rate of gate teleportations:', totals/totals_no_gate_checks, 'standard deviation:', math.sqrt((totals/totals_no_gate_checks)*(totals_no_gate_checks-totals))/totals_no_gate_checks)
# Out:
# failures: 3 totals: 4287
# logical failure rate: 0.0006997900629811056
# total accept rate: 0.4287 standard deviation: 0.004948901999433815
# accept rate of gate teleportations: 0.7420806647048641 standard deviation: 0.005755940880737615

# %%
p = failures/totals
n = totals
wilson = (1/(1 + 1/n))*(1/(2*n))*(math.sqrt(4*n*p*(1-p) + 1))
wilson_mean = 1/(1+ (1/n))*(p + (1/(2*n)))
print('logical failure rate confidence interval: (',  wilson_mean - wilson, ',',  wilson_mean + wilson, ')',)
# Out:
# logical failure rate confidence interval: ( 0.00039594373060996413 , 0.0012365189559572 )
